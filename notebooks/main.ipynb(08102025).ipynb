# %%
REPO_URL = "https://github.com/diligencefrozen/dcinside-data.git"
REPO_NAME = REPO_URL.rsplit("/", 1)[-1].replace(".git","")

import os, pathlib
if not (pathlib.Path("/content")/REPO_NAME).exists():
    # !git clone {REPO_URL}
# %cd /content/{REPO_NAME}
# !ls -R | head -200
# Out:
# Cloning into 'dcinside-data'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 120 (delta 27), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (120/120), 53.98 MiB | 11.97 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# /content/dcinside-data
# .:
# analysis
# Main.ipynb
# notebooks
# post-dataset
# README.md
# scripts
# src
# ss
#
# ./analysis:
# top_tokens.py
#
# ./notebooks:
# 01_eda.ipynb
#
# ./post-dataset:
# FrozenGallery_PostDataset(10202024-05012020).csv
# FrozenGallery_PostDataset(14gall_realMain_1).csv
# FrozenGallery_PostDataset(14gall_realMain_2).csv
# FrozenGallery_PostDataset(19gall_realMain_1).csv
# FrozenGallery_PostDataset(19gall_realMain_2).csv
# FrozenGallery_PostDataset(19gall_realMain_3).csv
# FrozenGallery_PostDataset(19gall_realMain_4).csv
# FrozenGallery_PostDataset(Main).zip
# FrozenGallery_PostDataset_TESTVERSION.csv
# ...

# %%
import sys, pathlib
cur = pathlib.Path.cwd()
found = None
for p in [cur, *cur.parents]:
    if (p/"src"/"build_main.py").exists():
        sys.path.insert(0, str(p/"src"))
        found = p
        break
print("repo root:", found)

from build_main import build_main
from preprocess import attach_clean_tokens
import stats as st
# Out:
# repo root: /content/dcinside-data

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path.cwd().parent / "src"))

from build_main import build_main
from preprocess import attach_clean_tokens
import stats as st
import pandas as pd

# %%
import os, pathlib, glob
print("CWD:", os.getcwd())
print("post-dataset exists?", (pathlib.Path.cwd().parent / "post-dataset").exists())
print("CSV count:", len(glob.glob("../post-dataset/*.csv")))
# Out:
# CWD: /content/dcinside-data
# post-dataset exists? False
# CSV count: 0

# %%
# !mkdir -p ./data
# !wget -O ./data/dcinside-data-main.zip \
  https://github.com/diligencefrozen/dcinside-data/archive/refs/heads/main.zip

import sys, pathlib
sys.path.append(str(pathlib.Path.cwd() / "src"))
from build_main import build_main
from preprocess import attach_clean_tokens

df = build_main(data_dir="./data", out_csv="./data/main.csv")
df = attach_clean_tokens(df)
df.to_csv("./data/main_clean.csv", index=False)
df.head()
# Out:
# --2025-08-10 13:47:05--  https://github.com/diligencefrozen/dcinside-data/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/diligencefrozen/dcinside-data/zip/refs/heads/main [following]
# --2025-08-10 13:47:05--  https://codeload.github.com/diligencefrozen/dcinside-data/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘./data/dcinside-data-main.zip’
#
# ./data/dcinside-dat     [         <=>        ]  53.95M  13.2MB/s    in 4.1s
#
# 2025-08-10 13:47:10 (13.2 MB/s) - ‘./data/dcinside-data-main.zip’ saved [56567349]
#         번호                     제목  \
# ...

# %%
daily, hourly, wday = st.activity(df)
authors = st.authors(df)
top_tokens, top_bigrams = st.tokens_bigrams(df, topn=200)
top_domains = st.body_domains(df)
corr = st.correlations(df)

# 확인용 미리보기
display(daily.tail(10), hourly, wday)
display(authors.head(20))
display(top_tokens.head(30), top_bigrams.head(30), top_domains.head(30))
corr
# Out:
#             date  posts
# 1565  2024-10-11     11
# 1566  2024-10-12     23
# 1567  2024-10-13     50
# 1568  2024-10-14     26
# 1569  2024-10-15     20
# 1570  2024-10-16     28
# 1571  2024-10-17     39
# 1572  2024-10-18     24
# 1573  2024-10-19     36
# 1574  2024-10-20     70
#     hour  posts
# 0      0  21257
# 1      1  13439
# 2      2  10017
# 3      3   6617
# 4      4   3833
# 5      5   1953
# 6      6   2769
# 7      7   2220
# 8      8   3245
# 9      9   3425
# 10    10   4984
# 11    11   6042
# 12    12  12083
# 13    13   7830
# 14    14   7636
# 15    15   7750
# 16    16   8325
# 17    17   8752
# 18    18  14933
# 19    19   9586
# 20    20  11032
# 21    21  10043
# 22    22  13008
# 23    23  13848
#    weekday  posts
# 0        0  30069
# 1        1  28356
# 2        2  28067
# 3        3  27489
# 4        4  28069
# 5        5  30019
# 6        6  32558
#                  글쓴이  posts   avg_rec   avg_view
# 0                 ㅇㅇ  53705  0.793502  63.091928
# ...
